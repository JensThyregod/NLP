# %%
from datasets import load_dataset
import Preprocessor as p

# %%
# Load the copenlu/answerable_tydiqa dataset
dataset = load_dataset("copenlu/answerable_tydiqa")

train_df = dataset['train'].to_pandas()
train_df = train_df[train_df['language'].isin(['indonesian', 'arabic', 'bengali'])]
train_df = p.DataFramePreprocessor(train_df, columns_to_tokenize=['document_plaintext', 'question_text'], remove_stopwords = False).df

val_df = dataset['validation'].to_pandas()
val_df = val_df[val_df['language'].isin(['indonesian', 'arabic', 'bengali'])]
val_df = p.DataFramePreprocessor(val_df, columns_to_tokenize=['document_plaintext', 'question_text'], remove_stopwords = False).df

# %%
train_df
# Out:
#                                             question_text  \
# 3                      চেঙ্গিস খান কোন বংশের রাজা ছিলেন ?
# 6                                 ما هي المسألة الشرقية ؟
# 7       dimanakah  Dr. Ernest François Eugène Douwes D...
# 8                              كم تبعد بيت لحم على القدس؟
# 11                        Siapa arsitek Balai Kota Seoul?
# ...                                                   ...
# 116058                             من هو ديفيد فنكلشتاين؟
# 116061                             من هو كريستيان دو دوف؟
# 116062           Kapan Kaisar Tang Gaozu mulai menjabat ?
# 116063                                 من ابتكر المثلجات؟
# 116064               বাংলা ব্যাকরণ মতে বিশেষণ কয় প্রকার ?
#
#               document_title    language  \
# 3                চেঙ্গিজ খান     bengali
# 6            المسألة الشرقية      arabic
# 7       Ernest Douwes Dekker  indonesian
# 8                    بيت لحم      arabic
# 11          Balai Kota Seoul  indonesian
# ...                      ...         ...
# 116058       ديفيد فنكلشتاين      arabic
# 116061       كريستيان دو دوف      arabic
# 116062     Kaisar Tang Gaozu  indonesian
# 116063                مثلجات      arabic
# 116064                বিশেষণ     bengali
#
#                                               annotations  \
# 3       {'answer_start': [414], 'answer_text': ['বোরজি...
# 6       {'answer_start': [88], 'answer_text': ['مسألة ...
# 7       {'answer_start': [45], 'answer_text': ['28 Agu...
# 8       {'answer_start': [171], 'answer_text': ['10 كم']}
# 11      {'answer_start': [38], 'answer_text': ['Yoo Ke...
# ...                                                   ...
# 116058        {'answer_start': [-1], 'answer_text': ['']}
# 116061        {'answer_start': [-1], 'answer_text': ['']}
# 116062        {'answer_start': [-1], 'answer_text': ['']}
# 116063        {'answer_start': [-1], 'answer_text': ['']}
# 116064        {'answer_start': [-1], 'answer_text': ['']}
#
#                                        document_plaintext  \
# 3       চেঙ্গিজ খান (মঙ্গোলীয়: Чингис Хаан  আ-ধ্ব-ব: ...
# 6       \n\nالمسألة الشرقية (بالإنجليزية: Eastern Ques...
# 7       Ernest Douwes Dekker wafat dini hari tanggal 2...
# 8       بيت لحم (بالسريانية: ܒܝܬ ܠܚܡ ؛ باليونانية: Βηθ...
# 11      Pada tanggal 18 Februari 2008, desain Yoo Kerl...
# ...                                                   ...
# 116058  تصنيف:أشخاص من مدينة نيويورك\nتصنيف:خريجو معهد...
# 116061  تصنيف:أعضاء أجانب في الجمعية الملكية\nتصنيف:أع...
# 116062  Hingga tahun 626, situasi makin memanas, Li Sh...
# 116063  وأشار هؤلاء الإخصائيون إلى أن “صداع الآيس كريم...
# 116064  উপমান: যার সাথে তুলনা করা হয়।\nউপমেয়: যাকে ত...
#
#                                              document_url  \
# 3       https://bn.wikipedia.org/wiki/%E0%A6%9A%E0%A7%...
# 6       https://ar.wikipedia.org/wiki/%D8%A7%D9%84%D9%...
# 7       https://id.wikipedia.org/wiki/Ernest%20Douwes%...
# 8       https://ar.wikipedia.org/wiki/%D8%A8%D9%8A%D8%...
# 11      https://id.wikipedia.org/wiki/Balai%20Kota%20S...
# ...                                                   ...
# 116058  https://ar.wikipedia.org/wiki/%D8%AF%D9%8A%D9%...
# 116061  https://ar.wikipedia.org/wiki/%D9%83%D8%B1%D9%...
# 116062  https://id.wikipedia.org/wiki/Kaisar%20Tang%20...
# 116063  https://ar.wikipedia.org/wiki/%D9%85%D8%AB%D9%...
# 116064  https://bn.wikipedia.org/wiki/%E0%A6%AC%E0%A6%...
#
#                                 document_plaintext_tokens  \
# 3       [চেঙ্গিজ, খান, মঙ্গোলীয়, чингис, хаан, আ-ধ্ব-...
# 6       [المسألة, الشرقية, بالإنجليزية, eastern, quest...
# 7       [ernest, douwes, dekker, wafat, dini, hari, ta...
# 8       [بيت, لحم, بالسريانية, ܒܝܬ, ܠܚܡ, ؛, باليونانية...
# 11      [pada, tanggal, 18, februari, 2008, desain, yo...
# ...                                                   ...
# 116058  [تصنيفأشخاص, من, مدينة, نيويورك, تصنيفخريجو, م...
# 116061  [تصنيفأعضاء, أجانب, في, الجمعية, الملكية, تصني...
# 116062  [hingga, tahun, 626, situasi, makin, memanas, ...
# 116063  [وأشار, هؤلاء, الإخصائيون, إلى, أن, “صداع, الآ...
# 116064  [উপমান, যার, সাথে, তুলনা, করা, হয়।, উপমেয়, য...
#
#                                      question_text_tokens
# 3               [চেঙ্গিস, খান, কোন, বংশের, রাজা, ছিলেন, ]
# 6                           [ما, هي, المسألة, الشرقية, ؟]
# 7       [dimanakah, dr, ernest, françois, eugène, douw...
# 8                       [كم, تبعد, بيت, لحم, على, القدس؟]
# 11                   [siapa, arsitek, balai, kota, seoul]
# ...                                                   ...
# 116058                        [من, هو, ديفيد, فنكلشتاين؟]
# 116061                       [من, هو, كريستيان, دو, دوف؟]
# 116062    [kapan, kaisar, tang, gaozu, mulai, menjabat, ]
# 116063                             [من, ابتكر, المثلجات؟]
# 116064        [বাংলা, ব্যাকরণ, মতে, বিশেষণ, কয়, প্রকার, ]
#
# [45771 rows x 8 columns]
